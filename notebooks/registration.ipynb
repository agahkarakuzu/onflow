# %% [markdown]
# # Bash environment variables

# %%
# %%bash
# cat <<EOF > env.sh
# # =============================
# # BIDS environment setup
# # =============================
#
# export PROJECT_ROOT="/mnt/c/Users/hapla/Documents/GitHub/albert-plante_project"
# export BIDS_ROOT="\${PROJECT_ROOT}/data"
# export SUBJECT="0733"
#
# # =============================
# # Derived and temp directories
# # =============================
#
# export WORKDIR="\${BIDS_ROOT}/derivatives/tmp_\${SUBJECT}"
# export RESULTSDIR="\${PROJECT_ROOT}/results/results_\${SUBJECT}"
# export TEMPLATE_DIR="\${BIDS_ROOT}/derivatives/templates"
#
#
# # =============================
# # Input images
# # =============================
#
# export MP2RAGE="\${BIDS_ROOT}/sub-\${SUBJECT}/T1w_MP2RAGE_UNI-DEN_defaced.nii.gz"
# export DWI="\${BIDS_ROOT}/sub-\${SUBJECT}/dwi.nii.gz"
# export rDWI="\${BIDS_ROOT}/sub-\${SUBJECT}/rdwi.nii.gz"
# export T1_MAP="\${BIDS_ROOT}/sub-\${SUBJECT}/T1_map.nii.gz"
# export SEG_DWI="\${BIDS_ROOT}/sub-\${SUBJECT}/DWI_seg.nii.gz"
# export SEG_MP2RAGE="\${BIDS_ROOT}/sub-\${SUBJECT}/T1w_seg.nii.gz"
# export FA_MAP="\${BIDS_ROOT}/sub-\${SUBJECT}/sub-\${SUBJECT}_scanner_FA.nii"
# export FA_TRACTO="\${BIDS_ROOT}/sub-\${SUBJECT}/sub-\${SUBJECT}_tractoflow_FA.nii.gz"
# export FA_MRTRIX="\${BIDS_ROOT}/sub-\${SUBJECT}/FA_mrtrix.nii.gz"
#
#
#
# # =============================
# # Templates / Atlases
# # =============================
#
# export MNI="\${TEMPLATE_DIR}/MNI152_T1_1mm.nii.gz"
# export ATLAS="\${TEMPLATE_DIR}/Atlas_MNI.nii.gz"
# export MNI_LABEL="\${TEMPLATE_DIR}/Optic_Nerve_Label_MNI.gz"
#
# # =============================
# # Registered outputs (generated)
# # =============================
#
# export DWI_TO_MP2RAGE="\${WORKDIR}/dwi2mp2rage"
# export MP2RAGE_TO_MNI="\${WORKDIR}/mp2rage2mni"
# export DWI_TO_MNI="\${WORKDIR}/dwi_mni.nii.gz"
# export SEG_DWI_TO_MP2RAGE="\${WORKDIR}/seg_dwi_to_mp2rage.nii.gz"
# export SEG_DWI_TO_MNI="\${WORKDIR}/seg_dwi_to_mni.nii.gz"
# export SEG_MP2RAGE_TO_MNI="\${WORKDIR}/seg_mp2rage_to_mni.nii.gz"
# export T1_MAP_TO_MNI="\${WORKDIR}/t1_map_to_mni.nii.gz"
# export MP2RAGE_MNI_ROI="\${WORKDIR}/mp2rage_mni_roi.nii.gz"
# export DWI_MNI_ROI="\${WORKDIR}/dwi_mni_roi.nii.gz"
# export CORRECTED_DWI="\${WORKDIR}/dwi_mni_corrected.nii.gz"
# export FINAL_SEG_DWI="\${WORKDIR}/seg_dwi_mni_corrected.nii.gz"
# export FA_TO_MP2RAGE="\${WORKDIR}/fa2mp2rage.nii.gz"
# export FA_TO_MNI="\${WORKDIR}/fa2mni.nii.gz"
# export FA_TO_DWI="\${WORKDIR}/fa2dwi"
# export CORRECTED_FA="\${WORKDIR}/fa2mni_corrected.nii.gz"
# export FA_TRACTO_TO_MP2RAGE="\${WORKDIR}/fat2mp2rage.nii.gz"
# export FA_TRACTO_TO_MNI="\${WORKDIR}/fat2mni.nii.gz"
# export FA_TRACTO_TO_DWI="\${WORKDIR}/fat2dwi"
# export CORRECTED_FA_TRACTO="\${WORKDIR}/fat2mni_corrected.nii.gz"
# export MRTRIX_TO_MP2RAGE="\${WORKDIR}/mrtrix2mp2rage.nii.gz"
# export MRTRIX_TO_MNI="\${WORKDIR}/mrtrix2mni.nii.gz"
# export CORRECTED_MRTRIX="\${WORKDIR}/mrtrix2mni_corrected.nii.gz"
#
# # =============================
# # Standardize space (MNI152) results outputs (generated)
# # =============================
#
# export MP2RAGE_MNI="\${RESULTSDIR}/mp2rage_mni.nii.gz"
# export DWI_MNI="\${RESULTSDIR}/dwi_mni.nii.gz"
# export SEG_MP2RAGE_MNI="\${RESULTSDIR}/seg_mp2rage_mni.nii.gz"
# export SEG_DWI_MNI="\${RESULTSDIR}/seg_dwi_mni.nii.gz"
# export T1_MAP_MNI="\${RESULTSDIR}/t1_map_mni.nii.gz"
# export FA_MAP_MNI="\${RESULTSDIR}/fa_map_mni.nii.gz"
# export FA_MAP_TRACTO_MNI="\${RESULTSDIR}/fa_map_tracto_mni.nii.gz"
# export MRTRIX_MNI="\${RESULTSDIR}/fa_map_mrtrix_mni.nii.gz"
# EOF
#
# source ./env.sh
# mkdir -p "$WORKDIR"
# mkdir -p "$RESULTSDIR"

# %% [markdown]
# # Image Registration

# %% [markdown]
# #### **1. Diffusion b0 image to MP2RAGE (Rigid Registration)**
#
# Because DWI are normally slabs rather than full brain image, the next registration may not always work reliably. Visually check the output, and if it's offset, rerun the registration.

# %%
# %%bash
# source env.sh
# export PATH=$HOME/ants/bin:$PATH
#
# # DWI to MP2RAGE
# antsRegistrationSyN.sh \
#   -d 3 -t r \
#   -f "$MP2RAGE" \
#   -m "$rDWI" \
#   -o "$DWI_TO_MP2RAGE"
# Out:
# --------------------------------------------------------------------------------------
#  Mapping parameters
# --------------------------------------------------------------------------------------
#  Dimensionality:           3
#  Output name prefix:       /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/dwi2mp2rage
#  Fixed images:             /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/sub-0760/T1w_MP2RAGE_UNI-DEN_defaced.nii
#  Moving images:            /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/sub-0760/rdwi.nii.gz
#  Mask images:
#  Initial transforms:
#  Number of threads:        1
#  Spline distance:          26
#  Linear gradient step:     0.1
#  SyN gradient step:        0.2
#  Transform type:           r
#  CC radius:                2
#  Precision:                d
#  Use histogram matching    0
#  Repro                     0
# ======================================================================================
#  antsRegistration call:
# --------------------------------------------------------------------------------------
# antsRegistration --verbose 1 --dimensionality 3 --float 0 --collapse-output-transforms 1 --output [ /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/dwi2mp2rage,/mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/dwi2mp2rageWarped.nii.gz,/mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/dwi2mp2rageInverseWarped.nii.gz ] --interpolation Linear --use-histogram-matching 0 --winsorize-image-intensities [ 0.005,0.995 ] --initial-moving-transform [ /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/sub-0760/T1w_MP2RAGE_UNI-DEN_defaced.nii,/mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/sub-0760/rdwi.nii.gz,1 ] --transform Rigid[ 0.1 ] --metric MI[ /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/sub-0760/T1w_MP2RAGE_UNI-DEN_defaced.nii,/mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/sub-0760/rdwi.nii.gz,1,32,Regular,0.25 ] --convergence [ 1000x500x250x100,1e-6,10 ] --shrink-factors 8x4x2x1 --smoothing-sigmas 3x2x1x0vox
# --------------------------------------------------------------------------------------
# All_Command_lines_OK
# Using double precision for computations.
# =============================================================================
# The composite transform comprises the following transforms (in order):
#   1. Center of mass alignment using fixed image: /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/sub-0760/T1w_MP2RAGE_UNI-DEN_defaced.nii and moving image: /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/sub-0760/rdwi.nii.gz (type = Euler3DTransform)
# =============================================================================
#   number of levels = 4
#   fixed image: /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/sub-0760/T1w_MP2RAGE_UNI-DEN_defaced.nii
#   moving image: /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/sub-0760/rdwi.nii.gz
# Dimension = 3
# Number of stages = 1
# Use histogram matching = false
# Winsorize image intensities = true
#   Lower quantile = 0.005
#   Upper quantile = 0.995
#
#
# Stage 1 State
#    Image metric = MattesMI
#      Fixed image = Image (0x559d40e75a00)
#   RTTI typeinfo:   itk::Image<double, 3u>
#   Reference Count: 2
#   Modified Time: 2320
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (none)
#   Source output name: (none)
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 0
#   UpdateMTime: 1929
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [176, 256, 256]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [176, 256, 256]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [176, 256, 256]
#   Spacing: [1, 1, 1]
#   Origin: [97.417, 132.353, -40.5687]
#   Direction:
# -0.99806 -0.0615427 -0.00944614
# 0.060964 -0.935087 -0.349136
# 0.0126538 -0.349035 0.937024
#
#   IndexToPointMatrix:
# -0.99806 -0.0615427 -0.00944614
# 0.060964 -0.935087 -0.349136
# 0.0126538 -0.349035 0.937024
#
#   PointToIndexMatrix:
# -0.99806 0.060964 0.0126538
# -0.0615427 -0.935087 -0.349035
# -0.00944614 -0.349136 0.937024
#
#   Inverse Direction:
# -0.99806 0.060964 0.0126538
# -0.0615427 -0.935087 -0.349035
# -0.00944614 -0.349136 0.937024
#
#   PixelContainer:
#     ImportImageContainer (0x559d40e77f10)
#       RTTI typeinfo:   itk::ImportImageContainer<unsigned long, double>
#       Reference Count: 1
#       Modified Time: 1926
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0x7fceb02c5010
#       Container manages memory: true
#       Size: 11534336
#       Capacity: 11534336
#
#      Moving image = Image (0x559d40e73840)
#   RTTI typeinfo:   itk::Image<double, 3u>
#   Reference Count: 2
#   Modified Time: 2321
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (none)
#   Source output name: (none)
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 0
#   UpdateMTime: 2318
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [150, 150, 30]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [150, 150, 30]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [150, 150, 30]
#   Spacing: [1.46667, 1.46667, 1.5]
#   Origin: [-101.061, 103.785, 24.0109]
#   Direction:
# 0.997239 -0.0706082 -0.023016
# -0.0735187 -0.982432 -0.171529
# 0.0105003 -0.172747 0.98491
#
#   IndexToPointMatrix:
# 1.46262 -0.103559 -0.0345239
# -0.107828 -1.4409 -0.257293
# 0.0154005 -0.253363 1.47737
#
#   PointToIndexMatrix:
# 0.679934 -0.0501263 0.00715927
# -0.0481419 -0.669839 -0.117782
# -0.015344 -0.114352 0.656607
#
#   Inverse Direction:
# 0.997239 -0.0735187 0.0105003
# -0.0706083 -0.982432 -0.172747
# -0.023016 -0.171529 0.98491
#
#   PixelContainer:
#     ImportImageContainer (0x559d40e79060)
#       RTTI typeinfo:   itk::ImportImageContainer<unsigned long, double>
#       Reference Count: 1
#       Modified Time: 2315
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0x559d413a9fb0
#       Container manages memory: true
#       Size: 675000
#       Capacity: 675000
#
#      Weighting = 1
#      Sampling strategy = regular
#      Number of bins = 32
#      Radius = 4
#      Sampling percentage  = 0.25
#    Transform = Rigid
#      Gradient step = 0.1
#      Update field sigma (voxel space) = 0
#      Total field sigma (voxel space) = 0
#      Update field time sigma = 0
#      Total field time sigma  = 0
#      Number of time indices = 0
#      Number of time point samples = 0
# Registration using 1 total stages.
#
# Stage 0
#   iterations = 1000x500x250x100
#   convergence threshold = 1e-06
#   convergence window size = 10
#   number of levels = 4
#   using the Mattes MI metric (number of bins = 32, weight = 1, use gradient filter = 0)
#   preprocessing:  winsorizing the image intensities
#   Shrink factors (level 1 out of 4): [8, 8, 8]
#   Shrink factors (level 2 out of 4): [4, 4, 4]
#   Shrink factors (level 3 out of 4): [2, 2, 2]
#   Shrink factors (level 4 out of 4): [1, 1, 1]
#   smoothing sigmas per level: [3, 2, 1, 0]
#   regular sampling (percentage = 0.25)
#
# *** Running Euler3DTransform registration ***
#
# DIAGNOSTIC,Iteration,metricValue,convergenceValue,ITERATION_TIME_INDEX,SINCE_LAST
#  2DIAGNOSTIC,     1, -5.885096269933e-01, 1.797693134862e+308, 9.6917e-01, 9.6917e-01,
#  2DIAGNOSTIC,     2, -5.914487546696e-01, 1.797693134862e+308, 9.7525e-01, 6.0771e-03,
#  2DIAGNOSTIC,     3, -5.933586977960e-01, 1.797693134862e+308, 9.8113e-01, 5.8839e-03,
#  2DIAGNOSTIC,     4, -5.955625452350e-01, 1.797693134862e+308, 9.8673e-01, 5.6028e-03,
#  2DIAGNOSTIC,     5, -5.987371338231e-01, 1.797693134862e+308, 9.9622e-01, 9.4831e-03,
#  2DIAGNOSTIC,     6, -6.011102227406e-01, 1.797693134862e+308, 1.0038e+00, 7.5538e-03,
#  2DIAGNOSTIC,     7, -6.019781079692e-01, 1.797693134862e+308, 1.0130e+00, 9.2380e-03,
#  2DIAGNOSTIC,     8, -6.036680266405e-01, 1.797693134862e+308, 1.0186e+00, 5.5568e-03,
#  2DIAGNOSTIC,     9, -6.059059614948e-01, 1.797693134862e+308, 1.0246e+00, 6.0730e-03,
#  2DIAGNOSTIC,    10, -6.089640100918e-01, 2.077353001750e-03, 1.0350e+00, 1.0403e-02,
#  2DIAGNOSTIC,    11, -6.118409747108e-01, 1.885806437147e-03, 1.0429e+00, 7.8251e-03,
#  2DIAGNOSTIC,    12, -6.100635348258e-01, 1.603773615273e-03, 1.0504e+00, 7.5631e-03,
#  2DIAGNOSTIC,    13, -6.238079812407e-01, 1.790988331342e-03, 1.0609e+00, 1.0490e-02,
#  2DIAGNOSTIC,    14, -6.258008279398e-01, 1.913262756979e-03, 1.0691e+00, 8.2178e-03,
#  2DIAGNOSTIC,    15, -6.316411608229e-01, 2.124580618623e-03, 1.0801e+00, 1.0944e-02,
#  2DIAGNOSTIC,    16, -6.251560382850e-01, 1.997227780348e-03, 1.1045e+00, 2.4431e-02,
#  2DIAGNOSTIC,    17, -6.251559554284e-01, 1.733559334165e-03, 1.1119e+00, 7.3981e-03,
#  2DIAGNOSTIC,    18, -6.251560304808e-01, 1.378939289101e-03, 1.1169e+00, 4.9450e-03,
#  2DIAGNOSTIC,    19, -6.251561573898e-01, 9.827604319440e-04, 1.1236e+00, 6.7520e-03,
#  2DIAGNOSTIC,    20, -6.251563719737e-01, 6.081113535665e-04, 1.1320e+00, 8.4121e-03,
#  2DIAGNOSTIC,    21, -6.251567347813e-01, 2.846204031705e-04, 1.1384e+00, 6.3620e-03,
# DIAGNOSTIC,Iteration,metricValue,convergenceValue,ITERATION_TIME_INDEX,SINCE_LAST
#  2DIAGNOSTIC,     1,

# DIAGNOSTIC,Iteration,metricValue,convergenceValue,ITERATION_TIME_INDEX,SINCE_LAST
#  2DIAGNOSTIC,     1, -3.662029226635e-01, 1.797693134862e+308, 1.1047e+01, 2.2892e+00,
#  2DIAGNOSTIC,     2, -3.667076707121e-01, 1.797693134862e+308, 1.2480e+01, 1.4324e+00,
#  2DIAGNOSTIC,     3, -3.672869873879e-01, 1.797693134862e+308, 1.4396e+01, 1.9160e+00,
#  2DIAGNOSTIC,     4, -3.682820730857e-01, 1.797693134862e+308, 1.7667e+01, 3.2713e+00,
#  2DIAGNOSTIC,     5, -3.688224439009e-01, 1.797693134862e+308, 2.0220e+01, 2.5533e+00,
#  2DIAGNOSTIC,     6, -3.689659707530e-01, 1.797693134862e+308, 2.3042e+01, 2.8219e+00,
#  2DIAGNOSTIC,     7, -3.689857919192e-01, 1.797693134862e+308, 2.7413e+01, 4.3704e+00,
#  2DIAGNOSTIC,     8, -3.689188934907e-01, 1.797693134862e+308, 3.1556e+01, 4.1429e+00,
#  2DIAGNOSTIC,     9, -3.689115326998e-01, 1.797693134862e+308, 3.4787e+01, 3.2316e+00,
#  2DIAGNOSTIC,    10, -3.689037042690e-01, 4.759021161846e-04, 3.7929e+01, 3.1419e+00,
#  2DIAGNOSTIC,    11, -3.689020815300e-01, 2.903411701470e-04, 4.0233e+01, 2.3034e+00,
#  2DIAGNOSTIC,    12, -3.688953005870e-01, 1.422272839513e-04, 4.2466e+01, 2.2330e+00,
#  2DIAGNOSTIC,    13, -3.688908481264e-01, 3.734996864822e-05, 4.4423e+01, 1.9574e+00,
#   Elapsed time (stage 0): 4.5679e+01
#
#
# Total elapsed time: 4.5683e+01
#  Registration finished. The antsRegistration call was:
# --------------------------------------------------------------------------------------
# antsRegistration --verbose 1 --dimensionality 3 --float 0 --collapse-output-transforms 1 --output [ /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/dwi2mp2rage,/mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/dwi2mp2rageWarped.nii.gz,/mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/dwi2mp2rageInverseWarped.nii.gz ] --interpolation Linear --use-histogram-matching 0 --winsorize-image-intensities [ 0.005,0.995 ] --initial-moving-transform [ /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/sub-0760/T1w_MP2RAGE_UNI-DEN_defaced.nii,/mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/sub-0760/rdwi.nii.gz,1 ] --transform Rigid[ 0.1 ] --metric MI[ /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/sub-0760/T1w_MP2RAGE_UNI-DEN_defaced.nii,/mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/sub-0760/rdwi.nii.gz,1,32,Regular,0.25 ] --convergence [ 1000x500x250x100,1e-6,10 ] --shrink-factors 8x4x2x1 --smoothing-sigmas 3x2x1x0vox
# --------------------------------------------------------------------------------------
# Moving image resampled into fixed space: /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/dwi2mp2rageWarped.nii.gz
# Fixed image resampled into moving space: /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/dwi2mp2rageInverseWarped.nii.gz
# --------------------------------------------------------------------------------------

# %% [markdown]
# #### **2. MP2RAGE to MNI 152 (Affine Registration)**

# %%
# %%bash
# source env.sh
# export PATH=$HOME/ants/bin:$PATH
#
# # MP2RAGE to MNI
# antsRegistrationSyN.sh \
#   -d 3 -t r \
#   -f "$MNI" \
#   -m "$MP2RAGE" \
#   -o "$MP2RAGE_TO_MNI"
# Out:
# --------------------------------------------------------------------------------------
#  Mapping parameters
# --------------------------------------------------------------------------------------
#  Dimensionality:           3
#  Output name prefix:       /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/mp2rage2mni
#  Fixed images:             /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/templates/MNI152_T1_1mm.nii.gz
#  Moving images:            /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/sub-0760/T1w_MP2RAGE_UNI-DEN_defaced.nii
#  Mask images:
#  Initial transforms:
#  Number of threads:        1
#  Spline distance:          26
#  Linear gradient step:     0.1
#  SyN gradient step:        0.2
#  Transform type:           r
#  CC radius:                2
#  Precision:                d
#  Use histogram matching    0
#  Repro                     0
# ======================================================================================
#  antsRegistration call:
# --------------------------------------------------------------------------------------
# antsRegistration --verbose 1 --dimensionality 3 --float 0 --collapse-output-transforms 1 --output [ /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/mp2rage2mni,/mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/mp2rage2mniWarped.nii.gz,/mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/mp2rage2mniInverseWarped.nii.gz ] --interpolation Linear --use-histogram-matching 0 --winsorize-image-intensities [ 0.005,0.995 ] --initial-moving-transform [ /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/templates/MNI152_T1_1mm.nii.gz,/mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/sub-0760/T1w_MP2RAGE_UNI-DEN_defaced.nii,1 ] --transform Rigid[ 0.1 ] --metric MI[ /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/templates/MNI152_T1_1mm.nii.gz,/mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/sub-0760/T1w_MP2RAGE_UNI-DEN_defaced.nii,1,32,Regular,0.25 ] --convergence [ 1000x500x250x100,1e-6,10 ] --shrink-factors 8x4x2x1 --smoothing-sigmas 3x2x1x0vox
# --------------------------------------------------------------------------------------
# All_Command_lines_OK
# Using double precision for computations.
# =============================================================================
# The composite transform comprises the following transforms (in order):
#   1. Center of mass alignment using fixed image: /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/templates/MNI152_T1_1mm.nii.gz and moving image: /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/sub-0760/T1w_MP2RAGE_UNI-DEN_defaced.nii (type = Euler3DTransform)
# =============================================================================
#   number of levels = 4
#   fixed image: /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/templates/MNI152_T1_1mm.nii.gz
#   moving image: /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/sub-0760/T1w_MP2RAGE_UNI-DEN_defaced.nii
# Dimension = 3
# Number of stages = 1
# Use histogram matching = false
# Winsorize image intensities = true
#   Lower quantile = 0.005
#   Upper quantile = 0.995
#
#
# Stage 1 State
#    Image metric = MattesMI
#      Fixed image = Image (0x55e83da3da70)
#   RTTI typeinfo:   itk::Image<double, 3u>
#   Reference Count: 2
#   Modified Time: 2316
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (none)
#   Source output name: (none)
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 0
#   UpdateMTime: 1927
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [182, 218, 182]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [182, 218, 182]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [182, 218, 182]
#   Spacing: [1, 1, 1]
#   Origin: [-90, 126, -72]
#   Direction:
# 1 0 0
# 0 -1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 1 0 0
# 0 -1 0
# 0 0 1
#
#   PointToIndexMatrix:
# 1 0 0
# 0 -1 0
# 0 0 1
#
#   Inverse Direction:
# 1 0 0
# 0 -1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (0x55e83da426f0)
#       RTTI typeinfo:   itk::ImportImageContainer<unsigned long, double>
#       Reference Count: 1
#       Modified Time: 1924
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0x7f0516e19010
#       Container manages memory: true
#       Size: 7221032
#       Capacity: 7221032
#
#      Moving image = Image (0x55e83da3b860)
#   RTTI typeinfo:   itk::Image<double, 3u>
#   Reference Count: 2
#   Modified Time: 2317
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (none)
#   Source output name: (none)
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 0
#   UpdateMTime: 2314
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [176, 256, 256]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [176, 256, 256]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [176, 256, 256]
#   Spacing: [1, 1, 1]
#   Origin: [97.417, 132.353, -40.5687]
#   Direction:
# -0.99806 -0.0615427 -0.00944614
# 0.060964 -0.935087 -0.349136
# 0.0126538 -0.349035 0.937024
#
#   IndexToPointMatrix:
# -0.99806 -0.0615427 -0.00944614
# 0.060964 -0.935087 -0.349136
# 0.0126538 -0.349035 0.937024
#
#   PointToIndexMatrix:
# -0.99806 0.060964 0.0126538
# -0.0615427 -0.935087 -0.349035
# -0.00944614 -0.349136 0.937024
#
#   Inverse Direction:
# -0.99806 0.060964 0.0126538
# -0.0615427 -0.935087 -0.349035
# -0.00944614 -0.349136 0.937024
#
#   PixelContainer:
#     ImportImageContainer (0x55e83da41b10)
#       RTTI typeinfo:   itk::ImportImageContainer<unsigned long, double>
#       Reference Count: 1
#       Modified Time: 2311
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0x7f0511618010
#       Container manages memory: true
#       Size: 11534336
#       Capacity: 11534336
#
#      Weighting = 1
#      Sampling strategy = regular
#      Number of bins = 32
#      Radius = 4
#      Sampling percentage  = 0.25
#    Transform = Rigid
#      Gradient step = 0.1
#      Update field sigma (voxel space) = 0
#      Total field sigma (voxel space) = 0
#      Update field time sigma = 0
#      Total field time sigma  = 0
#      Number of time indices = 0
#      Number of time point samples = 0
# Registration using 1 total stages.
#
# Stage 0
#   iterations = 1000x500x250x100
#   convergence threshold = 1e-06
#   convergence window size = 10
#   number of levels = 4
#   using the Mattes MI metric (number of bins = 32, weight = 1, use gradient filter = 0)
#   preprocessing:  winsorizing the image intensities
#   Shrink factors (level 1 out of 4): [8, 8, 8]
#   Shrink factors (level 2 out of 4): [4, 4, 4]
#   Shrink factors (level 3 out of 4): [2, 2, 2]
#   Shrink factors (level 4 out of 4): [1, 1, 1]
#   smoothing sigmas per level: [3, 2, 1, 0]
#   regular sampling (percentage = 0.25)
#
# *** Running Euler3DTransform registration ***
#
# DIAGNOSTIC,Iteration,metricValue,convergenceValue,ITERATION_TIME_INDEX,SINCE_LAST
#  2DIAGNOSTIC,     1, -3.626596958990e-01, 1.797693134862e+308, 2.3514e+00, 2.3514e+00,
#  2DIAGNOSTIC,     2, -3.642758561587e-01, 1.797693134862e+308, 2.3598e+00, 8.3480e-03,
#  2DIAGNOSTIC,     3, -3.663395666530e-01, 1.797693134862e+308, 2.3689e+00, 9.0928e-03,
#  2DIAGNOSTIC,     4, -3.693797680410e-01, 1.797693134862e+308, 2.3770e+00, 8.1511e-03,
#  2DIAGNOSTIC,     5, -3.756964921126e-01, 1.797693134862e+308, 2.3863e+00, 9.3379e-03,
#  2DIAGNOSTIC,     6, -3.929392844832e-01, 1.797693134862e+308, 2.3957e+00, 9.3322e-03,
#  2DIAGNOSTIC,     7, -4.320644074792e-01, 1.797693134862e+308, 2.4072e+00, 1.1550e-02,
#  2DIAGNOSTIC,     8, -5.707183863961e-01, 1.797693134862e+308, 2.4217e+00, 1.4448e-02,
#  2DIAGNOSTIC,     9, -7.418632868952e-01, 1.797693134862e+308, 2.4331e+00, 1.1479e-02,
#  2DIAGNOSTIC,    10, -7.506173605958e-01, 5.372523199887e-02, 2.4459e+00, 1.2789e-02,
#  2DIAGNOSTIC,    11, -7.537562875126e-01, 5.623164363708e-02, 2.4581e+00, 1.2129e-02,
#  2DIAGNOSTIC,    12, -7.594364986850e-01, 5.365548416453e-02, 2.4677e+00, 9.6779e-03,
#  2DIAGNOSTIC,    13, -7.648094386652e-01, 4.711023713841e-02, 2.4768e+00, 9.0890e-03,
#  2DIAGNOSTIC,    14, -7.720023308955e-01, 3.793585015682e-02, 2.4865e+00, 9.6900e-03,
#  2DIAGNOSTIC,    15, -7.751890593287e-01, 2.739504673750e-02, 2.4949e+00, 8.3802e-03,
#  2DIAGNOSTIC,    16, -7.771104561351e-01, 1.683129679742e-02, 2.5039e+00, 8.9571e-03,
#  2DIAGNOSTIC,    17, -7.778646982909e-01, 7.443076159722e-03, 2.5119e+00, 8.0369e-03,
#  2DIAGNOSTIC,    18, -7.799206650952e-01, 2.268292207146e-03, 2.5193e+00, 7.3619e-03,
#  2DIAGNOSTIC,    19, -7.809332478160e-01, 1.765222074817e-03, 2.5278e+00, 8.5781e-03,
#  2DIAGNOSTIC,    20, -4.877807070278e-01, 1.590533983360e-06, 1.1827e+02, 3.6745e+00,
#  2DIAGNOSTIC,    21, -4.877807070278e-01, 1.514792553857e-06, 1.2270e+02, 4.4293e+00,
#  2DIAGNOSTIC,    22, -4.877807070278e-01, 1.445936857754e-06, 1.2634e+02, 3.6413e+00,
#  2DIAGNOSTIC,    23, -4.877807070278e-01, 1.383068737391e-06, 1.3104e+02, 4.6986e+00,
#  2DIAGNOSTIC,    24, -4.877807070278e-01, 1.325439730901e-06, 1.3586e+02, 4.8209e+00,
#  2DIAGNOSTIC,    25, -4.877807070278e-01, 1.272421132688e-06, 1.4181e+02, 5.9489e+00,
#  2DIAGNOSTIC,    26, -4.877807070278e-01, 1.223480962785e-06, 1.4704e+02, 5.2267e+00,
#  2DIAGNOSTIC,    27, -4.877807070278e-01, 1.178166054570e-06, 1.5174e+02, 4.7016e+00,
#  2DIAGNOSTIC,    28, -4.877807070278e-01, 1.136087980469e-06, 1.5651e+02, 4.7712e+00,
#  2DIAGNOSTIC,    29, -4.877807070278e-01, 1.096911890132e-06, 1.6202e+02, 5.5154e+00,
#  2DIAGNOSTIC,    30, -4.877807070278e-01, 1.060347580580e-06, 1.6678e+02, 4.7568e+00,
#  2DIAGNOSTIC,    31, -4.877807070278e-01, 1.026142294934e-06, 1.7132e+02, 4.5401e+00,
#   Elapsed time (stage 0): 1.7467e+02
#
#
# Total elapsed time: 1.7469e+02
#  Registration finished. The antsRegistration call was:
# --------------------------------------------------------------------------------------
# antsRegistration --verbose 1 --dimensionality 3 --float 0 --collapse-output-transforms 1 --output [ /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/mp2rage2mni,/mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/mp2rage2mniWarped.nii.gz,/mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/mp2rage2mniInverseWarped.nii.gz ] --interpolation Linear --use-histogram-matching 0 --winsorize-image-intensities [ 0.005,0.995 ] --initial-moving-transform [ /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/templates/MNI152_T1_1mm.nii.gz,/mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/sub-0760/T1w_MP2RAGE_UNI-DEN_defaced.nii,1 ] --transform Rigid[ 0.1 ] --metric MI[ /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/templates/MNI152_T1_1mm.nii.gz,/mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/sub-0760/T1w_MP2RAGE_UNI-DEN_defaced.nii,1,32,Regular,0.25 ] --convergence [ 1000x500x250x100,1e-6,10 ] --shrink-factors 8x4x2x1 --smoothing-sigmas 3x2x1x0vox
# --------------------------------------------------------------------------------------
# Moving image resampled into fixed space: /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/mp2rage2mniWarped.nii.gz
# Fixed image resampled into moving space: /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/mp2rage2mniInverseWarped.nii.gz
# --------------------------------------------------------------------------------------

# %% [markdown]
# #### **3. Diffusion and MP2RAGE derivatives to MNI 152**

# %%
# %%bash
# source env.sh
# export PATH=$HOME/ants/bin:$PATH
#
# # DWI to MNI (via MP2RAGE to MNI Matrice)
# antsApplyTransforms \
#   -d 3 \
#   -i "${DWI_TO_MP2RAGE}Warped.nii.gz" \
#   -r "$MNI" \
#   -o "$DWI_TO_MNI" \
#   -n NearestNeighbor \
#   -t "${MP2RAGE_TO_MNI}0GenericAffine.mat"
#
# # DWI Segmentation to MP2RAGE (via DWI to MP2RAGE)
# antsApplyTransforms \
#   -d 3 \
#   -i "$SEG_DWI" \
#   -r "$MP2RAGE" \
#   -o "$SEG_DWI_TO_MP2RAGE" \
#   -n NearestNeighbor \
#   -t "${DWI_TO_MP2RAGE}0GenericAffine.mat"
#
# # DWI Segmentation to MNI (via MP2RAGE to MNI)
# antsApplyTransforms \
#   -d 3 \
#   -i "$SEG_DWI_TO_MP2RAGE" \
#   -r "$MNI" \
#   -o "$SEG_DWI_TO_MNI" \
#   -n NearestNeighbor \
#   -t "${MP2RAGE_TO_MNI}0GenericAffine.mat"
#
# # DWI FA to MP2RAGE (via DWI to MP2RAGE)
# antsApplyTransforms \
#   -d 3 \
#   -i "$FA_MAP" \
#   -r "$MP2RAGE" \
#   -o "$FA_TO_MP2RAGE" \
#   -n NearestNeighbor \
#   -t "${DWI_TO_MP2RAGE}0GenericAffine.mat"
#
# # DWI FA to MNI (via MP2RAGE to MNI)
# antsApplyTransforms \
#   -d 3 \
#   -i "$FA_TO_MP2RAGE" \
#   -r "$MNI" \
#   -o "$FA_TO_MNI" \
#   -n NearestNeighbor \
#   -t "${MP2RAGE_TO_MNI}0GenericAffine.mat"
#
# # DWI FA TRACTO to MP2RAGE (via DWI to MP2RAGE)
# antsApplyTransforms \
#   -d 3 \
#   -i "$FA_TRACTO" \
#   -r "$MP2RAGE" \
#   -o "$FA_TRACTO_TO_MP2RAGE" \
#   -n NearestNeighbor \
#   -t "${DWI_TO_MP2RAGE}0GenericAffine.mat"
#
# # DWI FA TRACTO to MNI (via MP2RAGE to MNI)
# antsApplyTransforms \
#   -d 3 \
#   -i "$FA_TRACTO_TO_MP2RAGE" \
#   -r "$MNI" \
#   -o "$FA_TRACTO_TO_MNI" \
#   -n NearestNeighbor \
#   -t "${MP2RAGE_TO_MNI}0GenericAffine.mat"
#
# # DWI FA MRTRIX to MP2RAGE (via DWI to MP2RAGE)
# antsApplyTransforms \
#   -d 3 \
#   -i "$FA_MRTRIX" \
#   -r "$MP2RAGE" \
#   -o "$MRTRIX_TO_MP2RAGE" \
#   -n NearestNeighbor \
#   -t "${DWI_TO_MP2RAGE}0GenericAffine.mat"
#
# # DWI FA MRTRIX to MNI (via MP2RAGE to MNI)
# antsApplyTransforms \
#   -d 3 \
#   -i "$MRTRIX_TO_MP2RAGE" \
#   -r "$MNI" \
#   -o "$MRTRIX_TO_MNI" \
#   -n NearestNeighbor \
#   -t "${MP2RAGE_TO_MNI}0GenericAffine.mat"
#
# # MP2RAGE Segmentation to MNI (via MP2RAGE to MNI)
# antsApplyTransforms \
#   -d 3 \
#   -i "$SEG_MP2RAGE" \
#   -r "$MNI" \
#   -o "$SEG_MP2RAGE_TO_MNI" \
#   -n NearestNeighbor \
#   -t "${MP2RAGE_TO_MNI}0GenericAffine.mat"
#
# # T1 MAP to MNI (via MP2RAGE to MNI)
# antsApplyTransforms \
#   -d 3 \
#   -i "$T1_MAP" \
#   -r "$MNI" \
#   -o "$T1_MAP_TO_MNI" \
#   -n NearestNeighbor \
#   -t "${MP2RAGE_TO_MNI}0GenericAffine.mat"

# %% [markdown]
# #### **4. ROI creation using MNI 152 standardized coordinates**

# %%
# %%bash
# source env.sh
# fslroi "${MP2RAGE_TO_MNI}Warped.nii.gz" "$MP2RAGE_MNI_ROI" 40 101 140 60 22 25
# fslroi "$DWI_TO_MNI" "$DWI_MNI_ROI" 40 101 140 60 22 25

# %% [markdown]
# #### **5. Diffusion to MP2RAGE (ROI Rigid Registration)**

# %%
# %%bash
# source env.sh
# export PATH=$HOME/ants/bin:$PATH
#
# # DWI to MP2RAGE (Rigid Registration)
# antsRegistrationSyN.sh \
#   -d 3 -t r \
#   -f "$MP2RAGE_MNI_ROI" \
#   -m "$DWI_MNI_ROI" \
#   -o "${WORKDIR}/roi2roi_"
# Out:
# --------------------------------------------------------------------------------------
#  Mapping parameters
# --------------------------------------------------------------------------------------
#  Dimensionality:           3
#  Output name prefix:       /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/roi2roi_
#  Fixed images:             /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/mp2rage_mni_roi.nii.gz
#  Moving images:            /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/dwi_mni_roi.nii.gz
#  Mask images:
#  Initial transforms:
#  Number of threads:        1
#  Spline distance:          26
#  Linear gradient step:     0.1
#  SyN gradient step:        0.2
#  Transform type:           r
#  CC radius:                2
#  Precision:                d
#  Use histogram matching    0
#  Repro                     0
# ======================================================================================
#  antsRegistration call:
# --------------------------------------------------------------------------------------
# antsRegistration --verbose 1 --dimensionality 3 --float 0 --collapse-output-transforms 1 --output [ /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/roi2roi_,/mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/roi2roi_Warped.nii.gz,/mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/roi2roi_InverseWarped.nii.gz ] --interpolation Linear --use-histogram-matching 0 --winsorize-image-intensities [ 0.005,0.995 ] --initial-moving-transform [ /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/mp2rage_mni_roi.nii.gz,/mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/dwi_mni_roi.nii.gz,1 ] --transform Rigid[ 0.1 ] --metric MI[ /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/mp2rage_mni_roi.nii.gz,/mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/dwi_mni_roi.nii.gz,1,32,Regular,0.25 ] --convergence [ 1000x500x250x100,1e-6,10 ] --shrink-factors 8x4x2x1 --smoothing-sigmas 3x2x1x0vox
# --------------------------------------------------------------------------------------
# All_Command_lines_OK
# Using double precision for computations.
# =============================================================================
# The composite transform comprises the following transforms (in order):
#   1. Center of mass alignment using fixed image: /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/mp2rage_mni_roi.nii.gz and moving image: /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/dwi_mni_roi.nii.gz (type = Euler3DTransform)
# =============================================================================
#   number of levels = 4
#   fixed image: /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/mp2rage_mni_roi.nii.gz
#   moving image: /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/dwi_mni_roi.nii.gz
# Dimension = 3
# Number of stages = 1
# Use histogram matching = false
# Winsorize image intensities = true
#   Lower quantile = 0.005
#   Upper quantile = 0.995
#
#
# Stage 1 State
#    Image metric = MattesMI
#      Fixed image = Image (0x562f9a181a20)
#   RTTI typeinfo:   itk::Image<double, 3u>
#   Reference Count: 2
#   Modified Time: 2316
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (none)
#   Source output name: (none)
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 0
#   UpdateMTime: 1927
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [101, 60, 25]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [101, 60, 25]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [101, 60, 25]
#   Spacing: [1, 1, 1]
#   Origin: [-50, -14, -50]
#   Direction:
# 1 0 0
# 0 -1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 1 0 0
# 0 -1 0
# 0 0 1
#
#   PointToIndexMatrix:
# 1 0 0
# 0 -1 0
# 0 0 1
#
#   Inverse Direction:
# 1 0 0
# 0 -1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (0x562f9a184ba0)
#       RTTI typeinfo:   itk::ImportImageContainer<unsigned long, double>
#       Reference Count: 1
#       Modified Time: 1924
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0x562f9a2b7750
#       Container manages memory: true
#       Size: 151500
#       Capacity: 151500
#
#      Moving image = Image (0x562f9a17c8f0)
#   RTTI typeinfo:   itk::Image<double, 3u>
#   Reference Count: 2
#   Modified Time: 2317
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (none)
#   Source output name: (none)
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 0
#   UpdateMTime: 2314
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [101, 60, 25]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [101, 60, 25]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [101, 60, 25]
#   Spacing: [1, 1, 1]
#   Origin: [-50, -14, -50]
#   Direction:
# 1 0 0
# 0 -1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 1 0 0
# 0 -1 0
# 0 0 1
#
#   PointToIndexMatrix:
# 1 0 0
# 0 -1 0
# 0 0 1
#
#   Inverse Direction:
# 1 0 0
# 0 -1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (0x562f9a1863b0)
#       RTTI typeinfo:   itk::ImportImageContainer<unsigned long, double>
#       Reference Count: 1
#       Modified Time: 2311
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0x562f9a3df5c0
#       Container manages memory: true
#       Size: 151500
#       Capacity: 151500
#
#      Weighting = 1
#      Sampling strategy = regular
#      Number of bins = 32
#      Radius = 4
#      Sampling percentage  = 0.25
#    Transform = Rigid
#      Gradient step = 0.1
#      Update field sigma (voxel space) = 0
#      Total field sigma (voxel space) = 0
#      Update field time sigma = 0
#      Total field time sigma  = 0
#      Number of time indices = 0
#      Number of time point samples = 0
# Registration using 1 total stages.
#
# Stage 0
#   iterations = 1000x500x250x100
#   convergence threshold = 1e-06
#   convergence window size = 10
#   number of levels = 4
#   using the Mattes MI metric (number of bins = 32, weight = 1, use gradient filter = 0)
#   preprocessing:  winsorizing the image intensities
#   Shrink factors (level 1 out of 4): [8, 8, 8]
#   Shrink factors (level 2 out of 4): [4, 4, 4]
#   Shrink factors (level 3 out of 4): [2, 2, 2]
#   Shrink factors (level 4 out of 4): [1, 1, 1]
#   smoothing sigmas per level: [3, 2, 1, 0]
#   regular sampling (percentage = 0.25)
#
# *** Running Euler3DTransform registration ***
#
# DIAGNOSTIC,Iteration,metricValue,convergenceValue,ITERATION_TIME_INDEX,SINCE_LAST
#  2DIAGNOSTIC,     1, -6.164399933487e-01, 1.797693134862e+308, 2.3108e-02, 2.3108e-02,
#  2DIAGNOSTIC,     2, -6.234011987993e-01, 1.797693134862e+308, 2.3225e-02, 1.1706e-04,
#  2DIAGNOSTIC,     3, -6.350720642826e-01, 1.797693134862e+308, 2.3339e-02, 1.1396e-04,
#  2DIAGNOSTIC,     4, -6.862702904629e-01, 1.797693134862e+308, 2.3470e-02, 1.3089e-04,
#  2DIAGNOSTIC,     5, -7.118106787731e-01, 1.797693134862e+308, 2.3585e-02, 1.1492e-04,
#  2DIAGNOSTIC,     6, -7.678177294865e-01, 1.797693134862e+308, 2.3703e-02, 1.1802e-04,
#  2DIAGNOSTIC,     7, -9.058768305711e-01, 1.797693134862e+308, 2.3856e-02, 1.5306e-04,
#  2DIAGNOSTIC,     8, -9.730681670978e-01, 1.797693134862e+308, 2.3990e-02, 1.3399e-04,
#  2DIAGNOSTIC,     9, -9.824054266585e-01, 1.797693134862e+308, 2.4157e-02, 1.6713e-04,
#  2DIAGNOSTIC,    10, -9.761404176416e-01, 3.688713835583e-02, 2.4432e-02, 2.7514e-04,
#  2DIAGNOSTIC,    11, -1.143829177973e+00, 3.689360862480e-02, 2.4691e-02, 2.5892e-04,
#  2DIAGNOSTIC,    12, -1.225535406869e+00, 3.569767449864e-02, 2.5085e-02, 3.9411e-04,
#  2DIAGNOSTIC,    13, -1.265227066357e+00, 3.273947596520e-02, 2.5377e-02, 2.9206e-04,
#  2DIAGNOSTIC,    14, -1.266274249568e+00, 2.873938150168e-02, 2.5739e-02, 3.6216e-04,
#  2DIAGNOSTIC,     5, -9.313796647676e-02, 1.797693134862e+308, 7.0594e-01, 4.0431e-02,
#  2DIAGNOSTIC,     6, -1.365678972198e-01, 1.797693134862e+308, 7.6100e-01, 5.5059e-02,
#  2DIAGNOSTIC,     7, -1.509485558522e-01, 1.797693134862e+308, 8.0593e-01, 4.4934e-02,
#  2DIAGNOSTIC,     8, -1.702680412519e-01, 1.797693134862e+308, 8.5014e-01, 4.4204e-02,
#  2DIAGNOSTIC,     9, -1.784226164717e-01, 1.797693134862e+308, 8.9406e-01, 4.3918e-02,
#  2DIAGNOSTIC,    10, -1.826156086415e-01, 8.204617349067e-02, 9.3888e-01, 4.4820e-02,
#  2DIAGNOSTIC,    11, -1.889752861187e-01, 7.108658611004e-02, 9.8971e-01, 5.0830e-02,
#  2DIAGNOSTIC,    12, -1.927910105600e-01, 5.742615692028e-02, 1.0389e+00, 4.9157e-02,
#  2DIAGNOSTIC,    13, -1.944003941577e-01, 4.246148464852e-02, 1.0806e+00, 4.1782e-02,
#  2DIAGNOSTIC,    14, -1.948334729257e-01, 2.790502271855e-02, 1.1209e+00, 4.0258e-02,
#  2DIAGNOSTIC,    15, -1.953092069250e-01, 1.616820519398e-02, 1.1779e+00, 5.7042e-02,
#  2DIAGNOSTIC,    16, -1.955318851721e-01, 1.023362178548e-02, 1.2266e+00, 4.8636e-02,
#  2DIAGNOSTIC,    17, -1.954846942823e-01, 5.847688426190e-03, 1.2946e+00, 6.8006e-02,
#  2DIAGNOSTIC,    18, -1.954764168227e-01, 3.560325894706e-03, 1.3687e+00, 7.4081e-02,
#  2DIAGNOSTIC,    19, -1.954454675443e-01, 2.044694169611e-03, 1.4332e+00, 6.4565e-02,
#  2DIAGNOSTIC,    20, -1.953992996626e-01, 8.987273537613e-04, 1.6089e+00, 1.7567e-01,
#  2DIAGNOSTIC,    21, -1.954078586352e-01, 3.440317666216e-04, 1.6709e+00, 6.1971e-02,
#  2DIAGNOSTIC,    22, -1.953923970904e-01, 1.244964210966e-04, 1.7253e+00, 5.4455e-02,
#  2DIAGNOSTIC,    23, -1.953753985232e-01, 3.869644181356e-05, 1.7711e+00, 4.5822e-02,
#   Elapsed time (stage 0): 1.8250e+00
#
#
# Total elapsed time: 1.8255e+00
#  Registration finished. The antsRegistration call was:
# --------------------------------------------------------------------------------------
# antsRegistration --verbose 1 --dimensionality 3 --float 0 --collapse-output-transforms 1 --output [ /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/roi2roi_,/mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/roi2roi_Warped.nii.gz,/mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/roi2roi_InverseWarped.nii.gz ] --interpolation Linear --use-histogram-matching 0 --winsorize-image-intensities [ 0.005,0.995 ] --initial-moving-transform [ /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/mp2rage_mni_roi.nii.gz,/mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/dwi_mni_roi.nii.gz,1 ] --transform Rigid[ 0.1 ] --metric MI[ /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/mp2rage_mni_roi.nii.gz,/mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/dwi_mni_roi.nii.gz,1,32,Regular,0.25 ] --convergence [ 1000x500x250x100,1e-6,10 ] --shrink-factors 8x4x2x1 --smoothing-sigmas 3x2x1x0vox
# --------------------------------------------------------------------------------------
# Moving image resampled into fixed space: /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/roi2roi_Warped.nii.gz
# Fixed image resampled into moving space: /mnt/c/Users/hapla/Documents/GitHub/albert-plante_project/data/derivatives/tmp_0760/roi2roi_InverseWarped.nii.gz
# --------------------------------------------------------------------------------------

# %% [markdown]
# #### **6. Diffusion derivatives to MP2RAGE (via ROI)**

# %%
# %%bash
# source env.sh
# export PATH=$HOME/ants/bin:$PATH
#
# # Corrected DWI to MP2RAGE (via ROI DWI to ROI MP2RAGE Matrice)
# antsApplyTransforms \
#   -d 3 \
#   -i "$DWI_TO_MNI" \
#   -r "${MP2RAGE_TO_MNI}Warped.nii.gz" \
#   -o "$CORRECTED_DWI" \
#   -n NearestNeighbor \
#   -t "${WORKDIR}/roi2roi_0GenericAffine.mat"
#
# # DWI Segmentation to MP2RAGE (via ROI DWI to ROI MP2RAGE Matrice)
# antsApplyTransforms \
#   -d 3 \
#   -i "$SEG_DWI_TO_MNI" \
#   -r "${MP2RAGE_TO_MNI}Warped.nii.gz" \
#   -o "$FINAL_SEG_DWI" \
#   -n NearestNeighbor \
#   -t "${WORKDIR}/roi2roi_0GenericAffine.mat"
#
# # Corrected FA Map to MNI (via ROI DWI to ROI MP2RAGE Matrice)
# antsApplyTransforms \
#   -d 3 \
#   -i "$FA_TO_MNI" \
#   -r "${MP2RAGE_TO_MNI}Warped.nii.gz" \
#   -o "$CORRECTED_FA" \
#   -n NearestNeighbor \
#   -t "${WORKDIR}/roi2roi_0GenericAffine.mat"
#
# # Corrected FA TRACTO Map to MNI (via ROI DWI to ROI MP2RAGE Matrice)
# antsApplyTransforms \
#   -d 3 \
#   -i "$FA_TRACTO_TO_MNI" \
#   -r "${MP2RAGE_TO_MNI}Warped.nii.gz" \
#   -o "$CORRECTED_FA_TRACTO" \
#   -n NearestNeighbor \
#   -t "${WORKDIR}/roi2roi_0GenericAffine.mat"
#
# # Corrected FA MRTRIX Map to MNI (via ROI DWI to ROI MP2RAGE Matrice)
# antsApplyTransforms \
#   -d 3 \
#   -i "$MRTRIX_TO_MNI" \
#   -r "${MP2RAGE_TO_MNI}Warped.nii.gz" \
#   -o "$CORRECTED_MRTRIX" \
#   -n NearestNeighbor \
#   -t "${WORKDIR}/roi2roi_0GenericAffine.mat"

# %% [markdown]
# #### **7. Creating results files**

# %%
# %%bash
# source env.sh
#
# # Create standardize space (MNI152) results files
# cp "${MP2RAGE_TO_MNI}Warped.nii.gz" "$MP2RAGE_MNI"
# cp "$SEG_MP2RAGE_TO_MNI" "$SEG_MP2RAGE_MNI"
# cp "$CORRECTED_DWI" "$DWI_MNI"
# cp "$FINAL_SEG_DWI" "$SEG_DWI_MNI"
# cp "$T1_MAP_TO_MNI" "$T1_MAP_MNI"
# cp "$CORRECTED_FA" "$FA_MAP_MNI"
# cp "$CORRECTED_FA_TRACTO" "$FA_MAP_TRACTO_MNI"
# cp "$CORRECTED_MRTRIX" "$MRTRIX_MNI"

# %% [markdown]
# #### **8. Delete temporary working directory**

# %%
# %%bash
# source env.sh
#
# # Delete temporary working directory
# rm "$WORKDIR$
